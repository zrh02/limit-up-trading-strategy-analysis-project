# %% [markdown]
# # 涨停封板细节对次日收益的影响分析
#
# 本 Notebook 分析首日封板时间、炸板次数、连板类型与次日收益之间的关系。分析范围仅限东方财富涨停池中具备封板细节字段的样本。

# %% [markdown]
# 数据口径：
# - 最终宽表总行数：20,393
# - 同时具备封板细节字段和次日收益的样本数：1,076
# - 样本日期范围：2026-06-11 至 2026-06-30
#
# 核心均值：
# - 次日开盘收益均值：1.87%
# - 次日最高收益均值：5.67%
# - 次日收盘收益均值：2.01%
# - 次日收盘上涨概率：60.22%

# %%
import pandas as pd
df = pd.read_csv('../data/processed/model_dataset.csv', dtype={'code': str}, low_memory=False)
df.shape

# %%
pd.read_csv('output/按首次封板时间分组.csv')

# %% [markdown]
# ![按首次封板时间分组的次日收益](output/next_returns_by_first_seal_time.png)

# %%
pd.read_csv('output/按炸板次数分组.csv')

# %% [markdown]
# ![按炸板次数分组的次日收益](output/next_returns_by_break_count.png)

# %%
pd.read_csv('output/按连板类型分组.csv')

# %% [markdown]
# ![按连板类型分组的次日收益](output/next_returns_by_streak.png)

# %% [markdown]
# ![首次封板时间与次日收盘收益](output/first_seal_time_scatter.png)

# %%
pd.read_csv('output/相关系数矩阵.csv', index_col=0)
