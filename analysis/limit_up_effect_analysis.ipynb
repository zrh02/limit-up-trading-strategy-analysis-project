# %% [markdown]
# # Limit-up seal-detail effect analysis
#
# This notebook analyzes whether first-day seal details are associated with next-day returns. Scope is restricted to samples with available Eastmoney limit-up pool seal-detail fields.

# %% [markdown]
# Data scope:
# - Full model dataset rows: 20,393
# - Rows with complete seal-detail fields and next-day returns: 1,076
# - Date range: 2026-06-11 to 2026-06-30
#
# Headline averages on usable seal-detail sample:
# - Next open return: 1.87%
# - Next high return: 5.67%
# - Next close return: 2.01%
# - Next close win rate: 60.22%

# %%
import pandas as pd
df = pd.read_csv('../data/processed/model_dataset.csv', dtype={'code': str}, low_memory=False)
df.shape

# %%
by_first = pd.read_csv('output/by_first_seal_time.csv')
by_first

# %% [markdown]
# ![Next-day returns by first seal time](output/next_returns_by_first_seal_time.png)

# %%
pd.read_csv('output/by_break_count.csv')

# %% [markdown]
# ![Next-day returns by break count](output/next_returns_by_break_count.png)

# %%
pd.read_csv('output/by_limit_up_streak.csv')

# %% [markdown]
# ![Next-day returns by board streak](output/next_returns_by_streak.png)

# %% [markdown]
# ![First seal time scatter](output/first_seal_time_scatter.png)

# %%
pd.read_csv('output/correlations.csv', index_col=0)
